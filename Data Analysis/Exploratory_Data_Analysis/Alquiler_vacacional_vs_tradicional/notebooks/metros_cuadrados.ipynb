# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
metros_cuad= pd.read_csv(r'C:\Users\funny\Desktop\Bootcamp\mesa_trabajo_core\repo_sept_23\proyectos\EDA\Data\metros_cuadrados.csv', sep=';')

metros_cuad
# Out:
#             Distrito  metros2
# 0          Extramurs    137.5
# 1            Patraix    131.7
# 2          Benicalap    130.8
# 3     Camins al Grau    129.3
# 4       Ciutat Vella    127.6
# 5              Jesus    124.9
# 6         l'eixample    123.8
# 7            Algiros    121.9
# 8           Rascanya    121.6
# 9           Campanar    119.1
# 10   Quatre Carreres    118.4
# 11  Poblats Maritims    115.3
# 12       l'olivereta    114.2
# 13         la saidia    111.1
# 14   el pla del real    104.4
# 15        Benimaclet     87.7

# %%
metros_cuad['Distrito'] = metros_cuad['Distrito'].str.lower()
metros_cuad =metros_cuad.rename(columns = {'Distrito':'distrito'})
metros_cuad
# Out:
#             distrito  metros2
# 0          extramurs    137.5
# 1            patraix    131.7
# 2          benicalap    130.8
# 3     camins al grau    129.3
# 4       ciutat vella    127.6
# 5              jesus    124.9
# 6         l'eixample    123.8
# 7            algiros    121.9
# 8           rascanya    121.6
# 9           campanar    119.1
# 10   quatre carreres    118.4
# 11  poblats maritims    115.3
# 12       l'olivereta    114.2
# 13         la saidia    111.1
# 14   el pla del real    104.4
# 15        benimaclet     87.7

# %%
metros_cuad.to_csv('metros_cuadrados')

# %%
# Establecer el estilo de Seaborn
sns.set(style="whitegrid")

# Tamaño de la figura
plt.figure(figsize=(12, 8))

# Utilizar una paleta de colores predefinida de Seaborn (Set2)
barplot = sns.barplot(data=metros_cuad, x='distrito', y='metros2', palette="Set2")

# Rotar los títulos de los distritos en el eje X
plt.xticks(rotation=45)

# Añadir título y etiquetas de ejes
plt.title('Superficie media de inmueble en metros cuadrados')
plt.xlabel('Distrito')
plt.ylabel('Superficie m2')

# Añadir separadores de miles en el eje Y (si es necesario)
barplot.get_yaxis().set_major_formatter(FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

# Mostrar la trama
plt.show()
# Out:
# C:\Users\funny\AppData\Local\Temp\ipykernel_12940\3518254059.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   barplot = sns.barplot(data=metros_cuad, x='distrito', y='metros2', palette="Set2")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\funny\Desktop\Bootcamp\mesa_trabajo_core\repo_sept_23\proyectos\EDA\notebooks\metros_cuadrados.ipynb Cell 5 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/funny/Desktop/Bootcamp/mesa_trabajo_core/repo_sept_23/proyectos/EDA/notebooks/metros_cuadrados.ipynb#W4sZmlsZQ%3D%3D?line=15'>16</a> plt.ylabel('Superficie m2')
# ...
